# %%
# Gradient Boosting Model Score : 0.88483
# KNeighborsRegressor Model Score : 0.68275
# LinearRegression Model Score : 0.57245
# Neural Network Model Score : -0.23611
# Random Forest Model Score : 0.92303
# Random Forest Model Score : 0.81995

modelScores = {
    'GradientBoosting': 0.88483,
    'KNeighborsRegressor': 0.68275,
    'linearRegressor': 0.57245,
    'NeuralNetwork': -0.23611,
    'RandomForest': 0.92303,
    'DecisionTreeRegressor': 0.81995,
    'XGBRegressor' : 0.93985,
}

# %%
import matplotlib.pyplot as plt

# Extracting model names and scores
models = list(modelScores.keys())
scores = list(modelScores.values())

# Plotting the scores
plt.figure(figsize=(10, 6))
plt.bar(models, scores, color='skyblue')
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Model Scores')
plt.ylim(-0.5, 1)  # Setting y-axis limits for better visualization
plt.xticks(rotation=45, ha='right')  # Rotating x-axis labels for better readability
plt.tight_layout()
plt.show()
