# %%
# Gradient Boosting Model Score : 0.88483
# KNeighborsRegressor Model Score : 0.68275
# LinearRegression Model Score : 0.57245
# Neural Network Model Score : -0.23611
# Random Forest Model Score : 0.92303
# Random Forest Model Score : 0.81995

TraningTime = {
    'GradientBoosting': 0.6571197509765625,
    'KNeighborsRegressor': 0.003003835678100586,
    'linearRegressor': 0.03448081016540527,
    'NeuralNetwork': 4.788327217102051,
    'RandomForest': 1.9920823574066162,
    'DecisionTreeRegressor': 0.05920720100402832,
    'XGBooster': 0.1414053440093994
}

# %%
import matplotlib.pyplot as plt

# Extracting model names and scores
models = list(TraningTime.keys())
scores = list(TraningTime.values())

# Plotting the scores
plt.figure(figsize=(10, 6))
plt.bar(models, scores, color='red')
plt.xlabel('Models')
plt.ylabel('Time')
plt.title('Model Training Time')
# plt.ylim(0, 1)  # Setting y-axis limits for better visualization
plt.xticks(rotation=45, ha='right')  # Rotating x-axis labels for better readability
plt.tight_layout()
plt.show()
